# %% [markdown]
# # 01 — Baseline Agent
#
# Develop and test the greedy heuristic baseline agent.

# %%
import sys
sys.path.insert(0, '../src')
from orbit_wars.observation import parse_observation
from orbit_wars.strategy import baseline_orders
from orbit_wars.actions import build_action

# %%
obs = {
    'step': 5, 'player': 1,
    'planets': [
        {'x': 10.0, 'y': 10.0, 'owner': 1, 'ships': 30.0, 'growth_rate': 2.0},
        {'x': 50.0, 'y': 50.0, 'owner': 0, 'ships': 5.0, 'growth_rate': 3.0},
        {'x': 90.0, 'y': 90.0, 'owner': 2, 'ships': 15.0, 'growth_rate': 2.0},
    ],
    'fleets': []
}

game = parse_observation(obs)
orders = baseline_orders(game)
action = build_action(orders)
print('Action:', action)
