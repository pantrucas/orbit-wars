# %% [markdown]
# # 00 — EDA: Orbit Wars
#
# Explore competition data, observation format, and action space.

# %%
# Load and inspect sample observation
import json
from pathlib import Path

# Place sample obs JSON in data/raw/ after downloading competition data
# sample_path = Path('../data/raw/sample_obs.json')
# obs = json.loads(sample_path.read_text())
# print(json.dumps(obs, indent=2))

# %%
# Inspect planet and fleet structure
sample_obs = {
    'step': 0,
    'player': 1,
    'planets': [
        {'x': 10.0, 'y': 20.0, 'owner': 1, 'ships': 10.0, 'growth_rate': 2.0},
        {'x': 80.0, 'y': 80.0, 'owner': 2, 'ships': 10.0, 'growth_rate': 2.0},
    ],
    'fleets': []
}
print('Planets:', len(sample_obs['planets']))
print('Fleets:', len(sample_obs['fleets']))
